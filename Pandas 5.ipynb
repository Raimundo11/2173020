# %%
import numpy as np
import pandas as pd

print (np.__version__)
print (np.__version__)
# Out:
# 1.20.3
# 1.20.3

# %%
n_rows=365*24
n_cols=2
cols=['cols1','cols2']

df=pd.DataFrame(np.random.randint(1,20,size=(n_rows,n_cols)),
                columns=cols)

df.index= pd.util.testing.makeDateIndex(n_rows,freq='H')
df
# Out:
#                      cols1  cols2
# 2000-01-01 00:00:00     12     11
# 2000-01-01 01:00:00     15     11
# 2000-01-01 02:00:00     17     15
# 2000-01-01 03:00:00      9     15
# 2000-01-01 04:00:00     19      7
# ...                    ...    ...
# 2000-12-30 19:00:00     10     16
# 2000-12-30 20:00:00     13     17
# 2000-12-30 21:00:00      9      1
# 2000-12-30 22:00:00      4      9
# 2000-12-30 23:00:00      1      1
#
# [8760 rows x 2 columns]

# %%
df.resample('M')['cols1'].sum().to_frame()
# Out:
#             cols1
# 2000-01-31   7489
# 2000-02-29   6867
# 2000-03-31   7573
# 2000-04-30   7193
# 2000-05-31   7499
# 2000-06-30   7249
# 2000-07-31   7669
# 2000-08-31   7415
# 2000-09-30   7266
# 2000-10-31   7308
# 2000-11-30   7286
# 2000-12-31   7056

# %%
df.resample('D')['cols1'].sum().to_frame()
# Out:
#             cols1
# 2000-01-01    272
# 2000-01-02    275
# 2000-01-03    205
# 2000-01-04    231
# 2000-01-05    228
# ...           ...
# 2000-12-26    209
# 2000-12-27    270
# 2000-12-28    263
# 2000-12-29    256
# 2000-12-30    226
#
# [365 rows x 1 columns]

# %%
pd.DataFrame({'col1':[1,2,3,4],
              'cols':[5,6,7,8]})
# Out:
#    col1  cols
# 0     1     5
# 1     2     6
# 2     3     7
# 3     4     8

# %%
n_rows=5
n_cols=3
arr=np.random.randint(1,20,size=(n_rows,n_cols))
arr
# Out:
# array([[18,  3, 14],
#        [18, 10,  6],
#        [ 8, 12, 18],
#        [ 6,  6,  6],
#        [14, 16, 15]])

# %%
pd.DataFrame(arr,columns=tuple('ABC'))
# Out:
#     A   B   C
# 0  18   3  14
# 1  18  10   6
# 2   8  12  18
# 3   6   6   6
# 4  14  16  15

# %%
pd.util.testing.makeDataFrame().head()
# Out:
# C:\Users\Lau_R\anaconda3\lib\site-packages\pandas\util\__init__.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#                    A         B         C         D
# xtGE7q4spc  0.609573  1.283196  0.003751  0.218814
# RXRaFTZvIH -0.154006 -0.848047  1.962258  0.158763
# Mp5oJ4VP2J  0.126492 -0.146154  0.963797 -0.369962
# few1iS8812  1.163212  1.776418  0.955119  0.091363
# vyqgNfxMRV  0.128064  1.040182  0.338992  1.104632

# %%
pd.util.testing.makeMixedDataFrame().head()
# Out:
#      A    B     C          D
# 0  0.0  0.0  foo1 2009-01-01
# 1  1.0  1.0  foo2 2009-01-02
# 2  2.0  0.0  foo3 2009-01-05
# 3  3.0  1.0  foo4 2009-01-06
# 4  4.0  0.0  foo5 2009-01-07

# %%
pd.util.testing.makeTimeDataFrame().head()
# Out:
#                    A         B         C         D
# 2000-01-03  1.527048 -1.991117 -0.901512  0.876348
# 2000-01-04  1.753924  1.841169 -0.083550 -0.177384
# 2000-01-05 -1.416275 -0.464743  1.159381  0.211701
# 2000-01-06  0.628948 -0.292087  0.085379 -0.550025
# 2000-01-07  2.279904 -0.001614 -0.372449 -0.433311

# %%
pd.util.testing.makeMissingDataFrame().head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10608/2690167706.py in <module>
# ----> 1 pd.util.testing.makeMissingDataFrame().head()
#
# AttributeError: module 'pandas.util.testing' has no attribute 'makeMissingDataFrame'

# %%
n_rows=5
n_cols=2
cols=['omset','operasional']
df=pd.DataFrame(np.random.randint(1,20, size=(n_rows,n_cols)),
                columns=cols)
df
# Out:
#    omset  operasional
# 0     15           14
# 1      6           12
# 2     15            2
# 3     16           11
# 4      2           12

# %%
df['omset']=df['omset']*100_000
df['operasional']=df['operasional']*10_000
df
# Out:
#      omset  operasional
# 0  1500000       140000
# 1   600000       120000
# 2  1500000        20000
# 3  1600000       110000
# 4   200000       120000

# %%
df.index=pd.util.testing.makeDateIndex(n_rows,freq='D')
df=df.reset_index()
df=df.rename(columns={'index':'tanggal'})
df
# Out:
#      tanggal    omset  operasional
# 0 2000-01-01  1500000       140000
# 1 2000-01-02   600000       120000
# 2 2000-01-03  1500000        20000
# 3 2000-01-04  1600000       110000
# 4 2000-01-05   200000       120000

# %%
formatku={'tanggal':'{:%d/%m/%Y}',
          'operasional':'Rp{:.2f}',
          'omset':'Rp{:.2f}'}
laporan=df.style.format(formatku)
laporan
# Out:
# <style type="text/css">
# </style>
# <table id="T_f068e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f068e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f068e_row0_col0" class="data row0 col0" >01/01/2000</td>
#       <td id="T_f068e_row0_col1" class="data row0 col1" >Rp1500000.00</td>
#       <td id="T_f068e_row0_col2" class="data row0 col2" >Rp140000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f068e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f068e_row1_col0" class="data row1 col0" >02/01/2000</td>
#       <td id="T_f068e_row1_col1" class="data row1 col1" >Rp600000.00</td>
#       <td id="T_f068e_row1_col2" class="data row1 col2" >Rp120000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f068e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f068e_row2_col0" class="data row2 col0" >03/01/2000</td>
#       <td id="T_f068e_row2_col1" class="data row2 col1" >Rp1500000.00</td>
#       <td id="T_f068e_row2_col2" class="data row2 col2" >Rp20000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f068e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f068e_row3_col0" class="data row3 col0" >04/01/2000</td>
#       <td id="T_f068e_row3_col1" class="data row3 col1" >Rp1600000.00</td>
#       <td id="T_f068e_row3_col2" class="data row3 col2" >Rp110000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f068e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f068e_row4_col0" class="data row4 col0" >05/01/2000</td>
#       <td id="T_f068e_row4_col1" class="data row4 col1" >Rp200000.00</td>
#       <td id="T_f068e_row4_col2" class="data row4 col2" >Rp120000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
type(laporan)
# Out:
# pandas.io.formats.style.Styler

# %%
laporan.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f068e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f068e_row0_col0" class="data row0 col0" >01/01/2000</td>
#       <td id="T_f068e_row0_col1" class="data row0 col1" >Rp1500000.00</td>
#       <td id="T_f068e_row0_col2" class="data row0 col2" >Rp140000.00</td>
#     </tr>
#     <tr>
#       <td id="T_f068e_row1_col0" class="data row1 col0" >02/01/2000</td>
#       <td id="T_f068e_row1_col1" class="data row1 col1" >Rp600000.00</td>
#       <td id="T_f068e_row1_col2" class="data row1 col2" >Rp120000.00</td>
#     </tr>
#     <tr>
#       <td id="T_f068e_row2_col0" class="data row2 col0" >03/01/2000</td>
#       <td id="T_f068e_row2_col1" class="data row2 col1" >Rp1500000.00</td>
#       <td id="T_f068e_row2_col2" class="data row2 col2" >Rp20000.00</td>
#     </tr>
#     <tr>
#       <td id="T_f068e_row3_col0" class="data row3 col0" >04/01/2000</td>
#       <td id="T_f068e_row3_col1" class="data row3 col1" >Rp1600000.00</td>
#       <td id="T_f068e_row3_col2" class="data row3 col2" >Rp110000.00</td>
#     </tr>
#     <tr>
#       <td id="T_f068e_row4_col0" class="data row4 col0" >05/01/2000</td>
#       <td id="T_f068e_row4_col1" class="data row4 col1" >Rp200000.00</td>
#       <td id="T_f068e_row4_col2" class="data row4 col2" >Rp120000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
laporan.set_caption('Data Omset dan Operasional')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f068e_">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f068e_row0_col0" class="data row0 col0" >01/01/2000</td>
#       <td id="T_f068e_row0_col1" class="data row0 col1" >Rp1500000.00</td>
#       <td id="T_f068e_row0_col2" class="data row0 col2" >Rp140000.00</td>
#     </tr>
#     <tr>
#       <td id="T_f068e_row1_col0" class="data row1 col0" >02/01/2000</td>
#       <td id="T_f068e_row1_col1" class="data row1 col1" >Rp600000.00</td>
#       <td id="T_f068e_row1_col2" class="data row1 col2" >Rp120000.00</td>
#     </tr>
#     <tr>
#       <td id="T_f068e_row2_col0" class="data row2 col0" >03/01/2000</td>
#       <td id="T_f068e_row2_col1" class="data row2 col1" >Rp1500000.00</td>
#       <td id="T_f068e_row2_col2" class="data row2 col2" >Rp20000.00</td>
#     </tr>
#     <tr>
#       <td id="T_f068e_row3_col0" class="data row3 col0" >04/01/2000</td>
#       <td id="T_f068e_row3_col1" class="data row3 col1" >Rp1600000.00</td>
#       <td id="T_f068e_row3_col2" class="data row3 col2" >Rp110000.00</td>
#     </tr>
#     <tr>
#       <td id="T_f068e_row4_col0" class="data row4 col0" >05/01/2000</td>
#       <td id="T_f068e_row4_col1" class="data row4 col1" >Rp200000.00</td>
#       <td id="T_f068e_row4_col2" class="data row4 col2" >Rp120000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
laporan.highlight_min('omset', color='pink')
laporan.highlight_max('omset', color='lightgreen')

laporan.highlight_min('operasional', color='lightblue')
laporan.highlight_max('operasional', color='grey')
# Out:
# <style type="text/css">
# #T_f068e_row0_col2 {
#   background-color: grey;
# }
# #T_f068e_row2_col2 {
#   background-color: lightblue;
# }
# #T_f068e_row3_col1 {
#   background-color: lightgreen;
# }
# #T_f068e_row4_col1 {
#   background-color: pink;
# }
# </style>
# <table id="T_f068e_">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f068e_row0_col0" class="data row0 col0" >01/01/2000</td>
#       <td id="T_f068e_row0_col1" class="data row0 col1" >Rp1500000.00</td>
#       <td id="T_f068e_row0_col2" class="data row0 col2" >Rp140000.00</td>
#     </tr>
#     <tr>
#       <td id="T_f068e_row1_col0" class="data row1 col0" >02/01/2000</td>
#       <td id="T_f068e_row1_col1" class="data row1 col1" >Rp600000.00</td>
#       <td id="T_f068e_row1_col2" class="data row1 col2" >Rp120000.00</td>
#     </tr>
#     <tr>
#       <td id="T_f068e_row2_col0" class="data row2 col0" >03/01/2000</td>
#       <td id="T_f068e_row2_col1" class="data row2 col1" >Rp1500000.00</td>
#       <td id="T_f068e_row2_col2" class="data row2 col2" >Rp20000.00</td>
#     </tr>
#     <tr>
#       <td id="T_f068e_row3_col0" class="data row3 col0" >04/01/2000</td>
#       <td id="T_f068e_row3_col1" class="data row3 col1" >Rp1600000.00</td>
#       <td id="T_f068e_row3_col2" class="data row3 col2" >Rp110000.00</td>
#     </tr>
#     <tr>
#       <td id="T_f068e_row4_col0" class="data row4 col0" >05/01/2000</td>
#       <td id="T_f068e_row4_col1" class="data row4 col1" >Rp200000.00</td>
#       <td id="T_f068e_row4_col2" class="data row4 col2" >Rp120000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
d1={'col1':[1,2,3],
    'col2':[10,20,30]}
df1=pd.DataFrame(d1)
df1
# Out:
#    col1  col2
# 0     1    10
# 1     2    20
# 2     3    30

# %%
d2={'col3':[4,5,6],
    'col4':[40,50,60]}
df2=pd.DataFrame(d2)
df2
# Out:
#    col3  col4
# 0     4    40
# 1     5    50
# 2     6    60

# %%
df=pd.merge(df1,df2,left_index=True,right_index=True)
df
# Out:
#    col1  col2  col3  col4
# 0     1    10     4    40
# 1     2    20     5    50
# 2     3    30     6    60
